# %%
pip install langchain langchain-google-genai langchain-core google-generativeai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install groq
# Out:
# ...
#
#   Obtaining dependency information for groq from https://files.pythonhosted.org/packages/5f/d6/645a081750e43f858b7d09dce5d8e1e76cf11e7e4bdba81252e04f78963d/groq-0.37.1-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/137.5 kB ? eta -:--:--
#    ----------------------------------- ---- 122.9/137.5 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 137.5/137.5 kB 2.1 MB/s eta 0:00:00
# ...
